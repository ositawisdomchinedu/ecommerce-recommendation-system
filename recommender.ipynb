# %% [markdown]
# ### Import Labraries

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import pandas as pd
import os
import glob

# %% [markdown]
# ### Load Model

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1548.06it/s]

# %% [markdown]
# ### Load Data

# %%
def load_all_csv(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    
    df_list = []
    
    for file in all_files:
        try:
            temp_df = pd.read_csv(file)
            temp_df['source_file'] = os.path.basename(file)
            df_list.append(temp_df)
        except Exception as e:
            print(f"Error loading {file}: {e}")
    
    df = pd.concat(df_list, ignore_index=True, sort=False)
    return df

# Load data
df = load_all_csv("data")

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15         3995.0      58.0  "₹3,995.00"      INR
# 1     4.5             67         2899.0      35.0  "₹2,899.00"      INR
# 2     4.4            226         2999.0      65.0  "₹2,999.00"      INR
# 3     4.4           1052         1675.0      52.0  "₹1,675.00"      INR
# 4     4.7             12         2899.0      17.0  "₹2,899.00"      INR
#
#                                               images  ... what_customers_said  \
# 0  http://assets.myntassets.com/assets/images/837...  ...                 NaN
# 1  http://assets.myntassets.com/assets/images/913...  ...                 NaN
# 2  http://assets.myntassets.com/assets/images/176...  ...                 NaN
# 3  http://assets.myntassets.com/assets/images/137...  ...                 NaN
# 4  http://assets.myntassets.com/assets/images/pro...  ...                 NaN
#
#   seller_name                                              sizes  \
# 0         NaN                               [{"size":"Onesize"}]
# 1         NaN                               [{"size":"Onesize"}]
# 2         NaN                                     [{"size":"S"}]
# 3         NaN                               [{"size":"Onesize"}]
# 4         NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                NaN
# 1                              ["rw-9136281_cae700"]                NaN
# 2  ["https://videos.myntassets.com/assets/videos/...                NaN
# 3  ["https://videos.myntassets.com/assets/videos/...                NaN
# 4                                                NaN                NaN
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                          NaN         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category    source_file
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks  backpacks.csv
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks  backpacks.csv
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks  backpacks.csv
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks  backpacks.csv
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe  bath-robe.csv
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (2000, 25)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category', 'source_file'],
#       dtype='str')

# %%
# Check for missing values
df.isna().sum()
# Out:
# product_id                   0
# title                        0
# product_description          0
# rating                       0
# ratings_count                0
# initial_price                0
# discount                   242
# final_price                  0
# currency                     0
# images                       0
# delivery_options             0
# product_details              0
# breadcrumbs                  0
# product_specifications       0
# amount_of_stars              0
# what_customers_said       1146
# seller_name                602
# sizes                        0
# videos                    1562
# seller_information         602
# variations                1124
# best_offer                   0
# more_offers                  0
# category                     0
# source_file                  0
# dtype: int64
